# %%
##Narrow Transformations
input_list=[1,2,3,4]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_rdd=sc.parallelize(input_list,4)
input_rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: 4</div>

# %%
input_rdd.map(lambda x:x**2).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [1, 4, 9, 16]</div>

# %%
def power_list(x):
  return x**2
input_rdd.map(power_list).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [1, 4, 9, 16]</div>

# %%
input_list1=["Spark","PySpark","Python","Hive"]
input_rdd2=sc.parallelize(input_list1,4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_rdd2.filter(lambda x:len(x)>=5).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;Spark&#39;, &#39;PySpark&#39;, &#39;Python&#39;]</div>

# %%
print([i for i in input_list1 if len(i)>=5])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Spark&#39;, &#39;PySpark&#39;, &#39;Python&#39;]
# </div>

# %%
itera=list(filter(lambda x:len(x)>5,input_list1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
itera
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;PySpark&#39;, &#39;Python&#39;]</div>

# %%
list(map(lambda x: len(x)>=5,input_list1))
#map(lambda x: 'lower' if x < 3 else 'higher', lst)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [True, True, True, False]</div>

# %%
def more_than(x):
  if len(x)>=5:
    return x
input_rdd2.map(more_than).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;Spark&#39;, &#39;PySpark&#39;, &#39;Python&#39;, None]</div>

# %%
def more_than_filter(x):
  if len(x)>=5:
    return x
input_rdd2.filter(more_than_filter).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [&#39;Spark&#39;, &#39;PySpark&#39;, &#39;Python&#39;]</div>

# %%
input_rdd2.map(lambda x:len(x)>=5).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [True, True, True, False]</div>

# %%
def filter_def(x):
  if len(x)>=5:
    return x
def map_def(x):
  x+=" in Big Data"
  return x
input_rdd2.filter(filter_def).map(map_def).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [&#39;Spark in Big Data&#39;, &#39;PySpark in Big Data&#39;, &#39;Python in Big Data&#39;]</div>

# %%
input_rdd2.filter(lambda x:len(x)>=5).map(lambda x:x+" in Big Data").collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;Spark in Big Data&#39;, &#39;PySpark in Big Data&#39;, &#39;Python in Big Data&#39;]</div>

# %%
input_2d_list=[["Spark","Scala","PySpark"],["Python","Java","CPP"],["Spring Boot","Flask","Django"]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_rdd3=sc.parallelize(input_2d_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_rdd3.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 8</div>

# %%
input_rdd3.flatMap(lambda x:x).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [&#39;Spark&#39;,
#  &#39;Scala&#39;,
#  &#39;PySpark&#39;,
#  &#39;Python&#39;,
#  &#39;Java&#39;,
#  &#39;CPP&#39;,
#  &#39;Spring Boot&#39;,
#  &#39;Flask&#39;,
#  &#39;Django&#39;]</div>

# %%
input_rdd3.flatMap(lambda x:x).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 9</div>

# %%
input_rdd3.map(lambda x:x).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [[&#39;Spark&#39;, &#39;Scala&#39;, &#39;PySpark&#39;],
#  [&#39;Python&#39;, &#39;Java&#39;, &#39;CPP&#39;],
#  [&#39;Spring Boot&#39;, &#39;Flask&#39;, &#39;Django&#39;]]</div>

# %%
input_rdd3.map(lambda x:x).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 3</div>

# %%
len(input_rdd3.flatMap(lambda x:x).collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 9</div>

# %%
#flatMap reduces the dimensions of the datastructure while map doesnt reduce the dimensions of the data structure
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Wide Transformations
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_list_4=[1,2,3,4,4,3,2,1]
input_rdd4=sc.parallelize(input_list_4,4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_rdd4.distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [4, 1, 2, 3]</div>

# %%
input_rdd4.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: 4</div>

# %%
len(input_rdd4.distinct().collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: 4</div>

# %%
input_rdd4.distinct().take(input_rdd4.distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [4, 1, 2, 3]</div>

# %%
input_rdd4.distinct().takeOrdered(len(input_rdd4.collect()),key=None)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: [1, 2, 3, 4]</div>

# %%
input_rdd4.repartition(8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: MapPartitionsRDD[52] at coalesce at NativeMethodAccessorImpl.java:0</div>

# %%
input_rdd4.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: 4</div>

# %%
input_rdd4.repartition(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: MapPartitionsRDD[57] at coalesce at NativeMethodAccessorImpl.java:0</div>

# %%
input_rdd4.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: 4</div>

# %%
# %sh pwd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/driver
# </div>

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/abcd.txt</td><td>abcd.txt</td><td>4</td></tr><tr><td>dbfs:/abcd1.txt</td><td>abcd1.txt</td><td>4</td></tr><tr><td>dbfs:/abcd3.txt</td><td>abcd3.txt</td><td>4</td></tr><tr><td>dbfs:/abcd4.txt</td><td>abcd4.txt</td><td>4</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /user/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/</td><td>hive/</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /><h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><br /></div>

# %%
dbutils.fs.put("abcd5.txt","Teja",False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 4 bytes.
# Out[38]: True</div>

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/abcd.txt</td><td>abcd.txt</td><td>4</td></tr><tr><td>dbfs:/abcd1.txt</td><td>abcd1.txt</td><td>4</td></tr><tr><td>dbfs:/abcd3.txt</td><td>abcd3.txt</td><td>4</td></tr><tr><td>dbfs:/abcd4.txt</td><td>abcd4.txt</td><td>4</td></tr><tr><td>dbfs:/abcd5.txt</td><td>abcd5.txt</td><td>4</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
input_Rdd=sc.textFile('/abcd.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: [&#39;Teja&#39;]</div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /><h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><br /></div>

# %%
dbutils.fs.ls('/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [FileInfo(path=&#39;dbfs:/FileStore/&#39;, name=&#39;FileStore/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/abcd.txt&#39;, name=&#39;abcd.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd1.txt&#39;, name=&#39;abcd1.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd3.txt&#39;, name=&#39;abcd3.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd4.txt&#39;, name=&#39;abcd4.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd5.txt&#39;, name=&#39;abcd5.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/&#39;, name=&#39;user/&#39;, size=0)]</div>

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/abcd.txt</td><td>abcd.txt</td><td>4</td></tr><tr><td>dbfs:/abcd1.txt</td><td>abcd1.txt</td><td>4</td></tr><tr><td>dbfs:/abcd3.txt</td><td>abcd3.txt</td><td>4</td></tr><tr><td>dbfs:/abcd4.txt</td><td>abcd4.txt</td><td>4</td></tr><tr><td>dbfs:/abcd5.txt</td><td>abcd5.txt</td><td>4</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls '/FileStore/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls '/FileStore/tables/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/a_csv.xlsx</td><td>a_csv.xlsx</td><td>8070</td></tr><tr><td>dbfs:/FileStore/tables/b.xlsx</td><td>b.xlsx</td><td>8059</td></tr><tr><td>dbfs:/FileStore/tables/c.txt</td><td>c.txt</td><td>38</td></tr><tr><td>dbfs:/FileStore/tables/spark-1.txt</td><td>spark-1.txt</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/spark-2.txt</td><td>spark-2.txt</td><td>33</td></tr><tr><td>dbfs:/FileStore/tables/spark-3.txt</td><td>spark-3.txt</td><td>33</td></tr><tr><td>dbfs:/FileStore/tables/spark.txt</td><td>spark.txt</td><td>0</td></tr></tbody></table></div>

# %%
input_Rdd1=sc.textFile('/FileStore/tables/spark-3.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Rdd1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: [&#39;spark&#39;, &#39;hive&#39;, &#39;map reduce&#39;, &#39;python&#39;]</div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /><h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><br /></div>

# %%
input_Rdd3=sc.textFile('/FileStore/tables/spark-2.txt',3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Rdd3.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: [&#39;spark&#39;, &#39;hive&#39;, &#39;map reduce&#39;, &#39;python&#39;]</div>

# %%
input_Rdd1.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: 2</div>

# %%
input_Rdd3.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: 3</div>

# %%
#Pair RDD
input_Pair=[(1,2),(2,4),(3,6),(4,8)]
input_Pair_RDD=sc.parallelize(input_Pair)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Pair_RDD.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: 8</div>

# %%
input_Pair_RDD.mapValues(lambda a:a*10).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: [(1, 20), (2, 40), (3, 60), (4, 80)]</div>

# %%
def multily(a):
  return a*10
input_Pair_RDD.mapValues(multily).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: [(1, 20), (2, 40), (3, 60), (4, 80)]</div>

# %%
def multiply(a):
  return a*10
  
input_Pair_RDD.mapValues(multiply).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: [(1, 20), (2, 40), (3, 60), (4, 80)]</div>

# %%
dbutils.fs.ls('/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: [FileInfo(path=&#39;dbfs:/FileStore/&#39;, name=&#39;FileStore/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/abcd.txt&#39;, name=&#39;abcd.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd1.txt&#39;, name=&#39;abcd1.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd3.txt&#39;, name=&#39;abcd3.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd4.txt&#39;, name=&#39;abcd4.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/abcd5.txt&#39;, name=&#39;abcd5.txt&#39;, size=4),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/user/&#39;, name=&#39;user/&#39;, size=0)]</div>

# %%
dbutils.fs.ls('/FileStore')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: [FileInfo(path=&#39;dbfs:/FileStore/tables/&#39;, name=&#39;tables/&#39;, size=0)]</div>

# %%
dbutils.fs.ls('/FileStore/tables/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: [FileInfo(path=&#39;dbfs:/FileStore/tables/a_csv.xlsx&#39;, name=&#39;a_csv.xlsx&#39;, size=8070),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/b.xlsx&#39;, name=&#39;b.xlsx&#39;, size=8059),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/c.txt&#39;, name=&#39;c.txt&#39;, size=38),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/spark-1.txt&#39;, name=&#39;spark-1.txt&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/spark-2.txt&#39;, name=&#39;spark-2.txt&#39;, size=33),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/spark-3.txt&#39;, name=&#39;spark-3.txt&#39;, size=33),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/spark.txt&#39;, name=&#39;spark.txt&#39;, size=0)]</div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /><h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><br /></div>

# %%
Pair_list_1=[("Python","OOPS"),("Java","OOPS"),("Java","SpringBoot"),("Python","FLASK")]
Pair_list_2=[("Python","PySpark"),("Java","Scala"),("Java","Hibernate"),("Python","AI")]

Pair_RDD_1=sc.parallelize(Pair_list_1)
Pair_RDD_2=sc.parallelize(Pair_list_2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: [(&#39;Python&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;SpringBoot&#39;),
#  (&#39;Python&#39;, &#39;FLASK&#39;)]</div>

# %%
Pair_RDD_2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: [(&#39;Python&#39;, &#39;PySpark&#39;),
#  (&#39;Java&#39;, &#39;Scala&#39;),
#  (&#39;Java&#39;, &#39;Hibernate&#39;),
#  (&#39;Python&#39;, &#39;AI&#39;)]</div>

# %%
Pair_RDD_1.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: 4</div>

# %%
Pair_RDD_2.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[63]: 4</div>

# %%
Pair_RDD_1.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: 8</div>

# %%
Pair_RDD_1.reduceByKey(lambda a,b:b+" Learning",numPartitions=4).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[65]: [(&#39;Python&#39;, &#39;FLASK Learning&#39;), (&#39;Java&#39;, &#39;SpringBoot Learning&#39;)]</div>

# %%
def reducing(a,b):
  return b+" Learning"
Pair_RDD_1.reduceByKey(reducing,numPartitions=8).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[66]: [(&#39;Java&#39;, &#39;SpringBoot Learning&#39;), (&#39;Python&#39;, &#39;FLASK Learning&#39;)]</div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[67]: [(&#39;Python&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;SpringBoot&#39;),
#  (&#39;Python&#39;, &#39;FLASK&#39;)]</div>

# %%
def multiply_1(a):
  return a*10
def filtering(b):
  return b[1]>50
input_Pair_RDD.mapValues(multiply_1).filter(filtering).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[68]: [(3, 60), (4, 80)]</div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[69]: [(&#39;Python&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;SpringBoot&#39;),
#  (&#39;Python&#39;, &#39;FLASK&#39;)]</div>

# %%
Pair_RDD_2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[70]: [(&#39;Python&#39;, &#39;PySpark&#39;),
#  (&#39;Java&#39;, &#39;Scala&#39;),
#  (&#39;Java&#39;, &#39;Hibernate&#39;),
#  (&#39;Python&#39;, &#39;AI&#39;)]</div>

# %%
Pair_RDD_1.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[71]: 8</div>

# %%
Pair_RDD_1.reduceByKey(lambda acc,n:acc+" & "+n).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: [(&#39;Java&#39;, &#39;OOPS &amp; SpringBoot&#39;), (&#39;Python&#39;, &#39;OOPS &amp; FLASK&#39;)]</div>

# %%
Pair_RDD_2.reduceByKey(lambda acc,n:acc+" & "+n).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[73]: [(&#39;Java&#39;, &#39;Scala &amp; Hibernate&#39;), (&#39;Python&#39;, &#39;PySpark &amp; AI&#39;)]</div>

# %%
def Joining(acc,n):
  return acc+" & "+n
  
Pair_RDD_1.reduceByKey(Joining).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[74]: [(&#39;Java&#39;, &#39;OOPS &amp; SpringBoot&#39;), (&#39;Python&#39;, &#39;OOPS &amp; FLASK&#39;)]</div>

# %%
def Joining_1(acc,N):
  return acc+" ^ "+N+" Learning"
Pair_RDD_2.reduceByKey(Joining_1).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[75]: [(&#39;Java&#39;, &#39;Scala ^ Hibernate Learning&#39;), (&#39;Python&#39;, &#39;PySpark ^ AI Learning&#39;)]</div>

# %%
initial_Value=0
sc.accumulator(initial_Value).value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[76]: 0</div>

# %%
def joining_using_ACC(initial_Value,N):
  return initial_Value+" ACC "+N
Pair_RDD_2.reduceByKey(joining_using_ACC).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[77]: [(&#39;Java&#39;, &#39;Scala ACC Hibernate&#39;), (&#39;Python&#39;, &#39;PySpark ACC AI&#39;)]</div>

# %%
Pair_RDD_1.distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: [(&#39;Java&#39;, &#39;OOPS&#39;),
#  (&#39;Java&#39;, &#39;SpringBoot&#39;),
#  (&#39;Python&#39;, &#39;OOPS&#39;),
#  (&#39;Python&#39;, &#39;FLASK&#39;)]</div>

# %%
Pair_RDD_3=sc.parallelize([(1,2),(1,2),(2,4),(2,5),(3,6),(4,5)],4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Pair_RDD_3.distinct().collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[80]: [(2, 4), (1, 2), (4, 5), (2, 5), (3, 6)]</div>

# %%
Pair_RDD_3.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[81]: 6</div>

# %%
Pair_RDD_3.distinct().reduceByKey(lambda acc,n:acc+n).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[82]: [(4, 5), (1, 2), (2, 9), (3, 6)]</div>

# %%
def check(a):
  return a[1]>5
Pair_RDD_3.distinct().reduceByKey(lambda acc,n:acc+n).filter(check).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: [(2, 9), (3, 6)]</div>

# %%
def redu(a,b):
  return b+" & "+a
Pair_RDD_2.reduceByKey(redu).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[84]: [(&#39;Java&#39;, &#39;Hibernate &amp; Scala&#39;), (&#39;Python&#39;, &#39;AI &amp; PySpark&#39;)]</div>

# %%
from functools import reduce
l=[1,2,3]
def add_num(a,b):
  return a+b
reduce(add_num,l)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: 6</div>

# %%
interset_1=[1,2,3,4,5,6,7]
input_RDD1=sc.parallelize(interset_1,4)
interset_2=[7,8,9,10,5,4,3,2,1]
input_RDD2=sc.parallelize(interset_2,4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_RDD1.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: 4</div>

# %%
input_RDD2.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: 4</div>

# %%
input_RDD1.intersection(input_RDD2).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[89]: [1, 2, 3, 4, 5, 7]</div>

# %%
input_RDD1.intersection(input_RDD2).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[90]: 6</div>

# %%
input_RDD3=sc.parallelize([1,2,3,4,5,4,3,2,1],4)
input_RDD4=sc.parallelize([2,3,4,5,1,2,3,4],4)
input_RDD3.intersection(input_RDD4).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[91]: [1, 2, 3, 4, 5]</div>

# %%
input_RDD3.intersection(input_RDD4).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: 5</div>

# %%
input_RDD5=sc.parallelize(["Java","Python","Spring Boot","Flask","Django"],4)
input_RDD6=sc.parallelize(["Flask","Django","Spring"],4)
input_RDD5.intersection(input_RDD6).filter(lambda a:len(a)>5).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: [&#39;Django&#39;]</div>

# %%
#Joins
input_Join_1=sc.parallelize([1,2,3,4],4)
input_Join_2=sc.parallelize([5,6,7,8],4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Join_3=sc.parallelize([(1,2),(3,4)],4)
input_Join_4=sc.parallelize([(1,4),(1,5),(3,8)],4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_Join_3.join(input_Join_4).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[96]: [(1, (2, 4)), (1, (2, 5)), (3, (4, 8))]</div>

# %%
def appending(a):
  ans=[]
  for i in a:
    ans.append("Learning "+i)
  return tuple(ans)
  
input_Join_5=sc.parallelize([("Java","Scala"),("Python","Flask")],4)
input_Join_6=sc.parallelize([("Java","Spring"),("Python","Big Data")],4)

input_Join_5.join(input_Join_6).mapValues(appending).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: [(&#39;Java&#39;, (&#39;Learning Scala&#39;, &#39;Learning Spring&#39;)),
#  (&#39;Python&#39;, (&#39;Learning Flask&#39;, &#39;Learning Big Data&#39;))]</div>

# %%
input_Join_7=sc.parallelize([(5,50),(6,60),(5,70)],4)
input_Join_8=sc.parallelize([(5,80),(6,90),(6,100)],4)

input_Join_7.join(input_Join_8).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[98]: [(5, (50, 80)), (5, (70, 80)), (6, (60, 90)), (6, (60, 100))]</div>

# %%
def f(a):
  ans=[]
  for i in a:
    ans.append(i+100)
  return tuple(ans)
input_Join_7.join(input_Join_8).mapValues(f).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[99]: [(5, (150, 180)), (5, (170, 180)), (6, (160, 190)), (6, (160, 200))]</div>

# %%
#Left Join
input_Join_7.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[100]: [(5, 50), (6, 60), (5, 70)]</div>

# %%
input_Join_8.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: [(5, 80), (6, 90), (6, 100)]</div>

# %%
input_Join_9=input_Join_8.union(sc.parallelize([(9,90),(10,100)],4))
input_Join_9.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: [(5, 80), (6, 90), (6, 100), (9, 90), (10, 100)]</div>

# %%
input_Join_9.leftOuterJoin(input_Join_7).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[103]: [(5, (80, 50)),
#  (5, (80, 70)),
#  (6, (90, 60)),
#  (6, (100, 60)),
#  (9, (90, None)),
#  (10, (100, None))]</div>

# %%
input_Join_10=input_Join_7.union(sc.parallelize([(120,130),(140,150)],4))
input_Join_9.rightOuterJoin(input_Join_10).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[104]: [(5, (80, 50)),
#  (5, (80, 70)),
#  (6, (90, 60)),
#  (6, (100, 60)),
#  (120, (None, 130)),
#  (140, (None, 150))]</div>

# %%
input_Join_10.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[105]: [(5, 50), (6, 60), (5, 70), (120, 130), (140, 150)]</div>

# %%
input_Join_9.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[106]: [(5, 80), (6, 90), (6, 100), (9, 90), (10, 100)]</div>

# %%
input_Join_9.groupWith(input_Join_10).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[107]: [(5,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a2940700&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d8b0&gt;)),
#  (6,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d700&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d280&gt;)),
#  (120,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a293db20&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293dcd0&gt;)),
#  (9,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a293de50&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d0a0&gt;)),
#  (10,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d790&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293dd30&gt;)),
#  (140,
#   (&lt;pyspark.resultiterable.ResultIterable at 0x7f61a293d730&gt;,
#    &lt;pyspark.resultiterable.ResultIterable at 0x7f61a293da60&gt;))]</div>

# %%
input_L1=[(1,2),(1,4),(2,6)]
input_L2=[(1,8),(3,10),(3,20)]
input_L1_RDD=sc.parallelize(input_L1,4)
input_L2_RDD=sc.parallelize(input_L2,4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_L1_RDD.join(input_L2_RDD).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[109]: [(1, (2, 8)), (1, (4, 8))]</div>

# %%
input_L1_RDD.leftOuterJoin(input_L2_RDD).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[110]: [(1, (2, 8)), (1, (4, 8)), (2, (6, None))]</div>

# %%
def f(a,b):
  return sum(list(a))+sum(list(b))

input_L1_RDD.leftOuterJoin(input_L2_RDD).reduceByKey(f).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[111]: [(1, 22), (2, (6, None))]</div>

# %%
def f(a,b):
  return sum(list(a))+sum(list(b))
final_list=input_L1_RDD.leftOuterJoin(input_L2_RDD).reduceByKey(f).collect()
ans=[]
for i in final_list:
  if type(i[1]) is tuple:
    ans.append((i[0],i[1][0]))
  else:
    ans.append(i)
print(ans)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(1, 22), (2, 6)]
# </div>

# %%
Pair_RDD_1=sc.parallelize([("Python",4),("Java",3),("Python",5),("java",4)],4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[114]: [(&#39;Python&#39;, 4), (&#39;Java&#39;, 3), (&#39;Python&#39;, 5), (&#39;java&#39;, 4)]</div>

# %%
Pair_RDD_2=sc.parallelize([("Python",10),("Java",8)],4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Pair_RDD_2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[116]: [(&#39;Python&#39;, 10), (&#39;Java&#39;, 8)]</div>

# %%
def a(a):
  ans=[]
  for i in a:
    ans.append(list(i))
  return ans
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[117]: [(&#39;Java&#39;, [[3], [8]]), (&#39;Python&#39;, [[4, 5], [10]]), (&#39;java&#39;, [[4], []])]</div>

# %%
def a(a):
  ans=[]
  for i in a:
    ans.append(list(i))
  return ans
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda x:x).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[118]: [(&#39;Java&#39;, [3]),
#  (&#39;Java&#39;, [8]),
#  (&#39;Python&#39;, [4, 5]),
#  (&#39;Python&#39;, [10]),
#  (&#39;java&#39;, [4]),
#  (&#39;java&#39;, [])]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMap(lambda a:a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[119]: [&#39;Java&#39;, [[3], [8]], &#39;Python&#39;, [[4, 5], [10]], &#39;java&#39;, [[4], []]]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda a:a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[120]: [(&#39;Java&#39;, [3]),
#  (&#39;Java&#39;, [8]),
#  (&#39;Python&#39;, [4, 5]),
#  (&#39;Python&#39;, [10]),
#  (&#39;java&#39;, [4]),
#  (&#39;java&#39;, [])]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[121]: [(&#39;Java&#39;, [[3], [8]]), (&#39;Python&#39;, [[4, 5], [10]]), (&#39;java&#39;, [[4], []])]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda a:a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[122]: [(&#39;Java&#39;, [3]),
#  (&#39;Java&#39;, [8]),
#  (&#39;Python&#39;, [4, 5]),
#  (&#39;Python&#39;, [10]),
#  (&#39;java&#39;, [4]),
#  (&#39;java&#39;, [])]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda a:a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[123]: [(&#39;Java&#39;, [3]),
#  (&#39;Java&#39;, [8]),
#  (&#39;Python&#39;, [4, 5]),
#  (&#39;Python&#39;, [10]),
#  (&#39;java&#39;, [4]),
#  (&#39;java&#39;, [])]</div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[124]: [(&#39;Python&#39;, 4), (&#39;Java&#39;, 3), (&#39;Python&#39;, 5), (&#39;java&#39;, 4)]</div>

# %%
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda a:a).groupByKey().mapValues(list).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[125]: [(&#39;Java&#39;, [[3], [8]]), (&#39;Python&#39;, [[4, 5], [10]]), (&#39;java&#39;, [[4], []])]</div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[126]: [(&#39;Python&#39;, 4), (&#39;Java&#39;, 3), (&#39;Python&#39;, 5), (&#39;java&#39;, 4)]</div>

# %%
def f(a,b):
  z=[]
  z.append(a)
  z.append(b)
  return z
Pair_RDD_1.reduceByKey(f).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[127]: [(&#39;Python&#39;, [4, 5]), (&#39;Java&#39;, 3), (&#39;java&#39;, 4)]</div>

# %%
def a(ab):
  ans=[]
  for i in ab:
    ans.append(list(i))
  return ans
Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[128]: [(&#39;Java&#39;, [[3], [8]]), (&#39;Python&#39;, [[4, 5], [10]]), (&#39;java&#39;, [[4], []])]</div>

# %%
def ab(a,b):
  z=[]
  z.append(list((a,b)))
  return z

Pair_RDD_1.cogroup(Pair_RDD_2).mapValues(a).flatMapValues(lambda a:a).groupByKey().mapValues(list).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[129]: [(&#39;Java&#39;, [[3], [8]]), (&#39;Python&#39;, [[4, 5], [10]]), (&#39;java&#39;, [[4], []])]</div>

# %%
Pair_RDD_1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[130]: [(&#39;Python&#39;, 4), (&#39;Java&#39;, 3), (&#39;Python&#39;, 5), (&#39;java&#39;, 4)]</div>

# %%
Pair_RDD_2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[131]: [(&#39;Python&#39;, 10), (&#39;Java&#39;, 8)]</div>

# %%
Pair_RDD_1.join(Pair_RDD_2).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[132]: [(&#39;Java&#39;, (3, 8)), (&#39;Python&#39;, (4, 10)), (&#39;Python&#39;, (5, 10))]</div>

# %%
Pair_RDD_1.join(Pair_RDD_2).mapValues(lambda a:list(a)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[133]: [(&#39;Java&#39;, [3, 8]), (&#39;Python&#39;, [4, 10]), (&#39;Python&#39;, [5, 10])]</div>

# %%
def f(a,b):
  a.extend(b)
  return a
Pair_RDD_1.join(Pair_RDD_2).mapValues(lambda a:list(a)).reduceByKey(f).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[134]: [(&#39;Java&#39;, [3, 8]), (&#39;Python&#39;, [4, 10, 5, 10])]</div>

# %%
Pair_RDD_1.join(Pair_RDD_2).mapValues(lambda a:list(a)).reduceByKey(f).mapValues(lambda a:sum(a)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: [(&#39;Java&#39;, 11), (&#39;Python&#39;, 29)]</div>

# %%
input_list=[("Kohli",10),("virat",20),("dhoni",40),("virat",50),("dhoni",60)]
input_RDD=sc.parallelize(input_list,4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
input_RDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[137]: [(&#39;Kohli&#39;, 10), (&#39;virat&#39;, 20), (&#39;dhoni&#39;, 40), (&#39;virat&#39;, 50), (&#39;dhoni&#39;, 60)]</div>

# %%
input_RDD.groupByKey().mapValues(list).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[138]: [(&#39;virat&#39;, [20, 50]), (&#39;Kohli&#39;, [10]), (&#39;dhoni&#39;, [40, 60])]</div>

# %%
input_RDD.groupByKey().mapValues(list).mapValues(lambda a:sum(a)/len(a)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[139]: [(&#39;virat&#39;, 35.0), (&#39;Kohli&#39;, 10.0), (&#39;dhoni&#39;, 50.0)]</div>

# %%
input_RDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[140]: [(&#39;Kohli&#39;, 10), (&#39;virat&#39;, 20), (&#39;dhoni&#39;, 40), (&#39;virat&#39;, 50), (&#39;dhoni&#39;, 60)]</div>

# %%
input_RDD.pipe('cat').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[142]: [&#34;(&#39;Kohli&#39;, 10)&#34;,
#  &#34;(&#39;virat&#39;, 20)&#34;,
#  &#34;(&#39;dhoni&#39;, 40)&#34;,
#  &#34;(&#39;virat&#39;, 50)&#34;,
#  &#34;(&#39;dhoni&#39;, 60)&#34;]</div>

# %%
input_RDD.pipe('ls').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[143]: [&#39;conf&#39;,
#  &#39;eventlogs&#39;,
#  &#39;ganglia&#39;,
#  &#39;logs&#39;,
#  &#39;metastore_db&#39;,
#  &#39;preload_class.lst&#39;,
#  &#39;conf&#39;,
#  &#39;eventlogs&#39;,
#  &#39;ganglia&#39;,
#  &#39;logs&#39;,
#  &#39;metastore_db&#39;,
#  &#39;preload_class.lst&#39;,
#  &#39;conf&#39;,
#  &#39;eventlogs&#39;,
#  &#39;ganglia&#39;,
#  &#39;logs&#39;,
#  &#39;metastore_db&#39;,
#  &#39;preload_class.lst&#39;,
#  &#39;conf&#39;,
#  &#39;eventlogs&#39;,
#  &#39;ganglia&#39;,
#  &#39;logs&#39;,
#  &#39;metastore_db&#39;,
#  &#39;preload_class.lst&#39;]</div>

# %%
input_RDD.pipe("pwd").collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[144]: [&#39;/databricks/driver&#39;,
#  &#39;/databricks/driver&#39;,
#  &#39;/databricks/driver&#39;,
#  &#39;/databricks/driver&#39;]</div>

# %%
input_RDD.pipe("pwd").take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[145]: [&#39;/databricks/driver&#39;]</div>

# %%
input_RDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[146]: [(&#39;Kohli&#39;, 10), (&#39;virat&#39;, 20), (&#39;dhoni&#39;, 40), (&#39;virat&#39;, 50), (&#39;dhoni&#39;, 60)]</div>

# %%
input_RDD.reduceByKey(lambda a,b:a+b).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[147]: [(&#39;virat&#39;, 70), (&#39;Kohli&#39;, 10), (&#39;dhoni&#39;, 100)]</div>

# %%
input_RDD.groupByKey().mapValues(list).mapValues(lambda a:sum(a)/len(a)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[148]: [(&#39;virat&#39;, 35.0), (&#39;Kohli&#39;, 10.0), (&#39;dhoni&#39;, 50.0)]</div>

# %%
def first(a):
  return [a]
def second(a,b):
  a.append(b)
  return a
def third(a,b):
  a.extend(b)
  return a
input_RDD.combineByKey(first,second,third).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[150]: [(&#39;virat&#39;, [20, 50]), (&#39;Kohli&#39;, [10]), (&#39;dhoni&#39;, [40, 60])]</div>

# %%
input_RDD.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[160]: [(&#39;Kohli&#39;, 10), (&#39;virat&#39;, 20), (&#39;dhoni&#39;, 40), (&#39;virat&#39;, 50), (&#39;dhoni&#39;, 60)]</div>

# %%
def first(a):
  return (a,1)
def second(a,b):
  return a[0]+b,a[1]+1
def third(a,b):
  return (a[0]+b[0],a[1]+b[1])
input_RDD.combineByKey(first,second,third).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[161]: [(&#39;virat&#39;, (70, 2)), (&#39;Kohli&#39;, (10, 1)), (&#39;dhoni&#39;, (100, 2))]</div>

# %%
input_RDD.combineByKey(first,second,third).mapValues(lambda a:a[0]/a[1]).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[162]: [(&#39;virat&#39;, 35.0), (&#39;Kohli&#39;, 10.0), (&#39;dhoni&#39;, 50.0)]</div>

# %%
input_RDD.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[163]: 4</div>

# %%
input_RDD.repartition(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[164]: MapPartitionsRDD[490] at coalesce at NativeMethodAccessorImpl.java:0</div>

# %%
input_RDD.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[165]: 4</div>

# %%
input_RDD.coalesce(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[167]: CoalescedRDD[491] at coalesce at NativeMethodAccessorImpl.java:0</div>

# %%
input_RDD.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[168]: 4</div>

# %%
def first(a):
  return (a,1)
def second(a,b):
  return a[0]+b,a[1]+1
def third(a,b):
  return (a[0]+b[0],a[1]+b[1])
import time
begin=time.time()
input_RDD.groupByKey().mapValues(list).mapValues(lambda a:sum(a)/len(a)).collect()
end=time.time()
exec_time=end-begin
print(exec_time)
begin_1=time.time()
input_RDD.combineByKey(first,second,third).mapValues(lambda a:a[0]/a[1]).collect()
end_1=time.time()
exec_time_1=end_1-begin_1
print(exec_time_1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.2600386142730713
# 0.22556567192077637
# </div>

# %%
input_RDD.repartition(2).getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[172]: 2</div>

# %%
import time
repartition_time_begin=time.time()
print(input_RDD.repartition(2).getNumPartitions())
repartition_time_end=time.time()
repartition_time=repartition_time_end-repartition_time_begin
coalesce_time_begin=time.time()
print(input_RDD.coalesce(2).getNumPartitions())
coalesce_time_end=time.time()
coalesce_time=coalesce_time_end-coalesce_time_begin
print(repartition_time)
print(coalesce_time)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2
# 2
# 0.01716160774230957
# 0.009719371795654297
# </div>

# %%
def second(a,b):
  return a+b
def third(a,b):
  return a+b
input_RDD.aggregateByKey((0),second,third).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[189]: [(&#39;virat&#39;, 70), (&#39;Kohli&#39;, 10), (&#39;dhoni&#39;, 100)]</div>

# %%
word_list=[("hello",1),("world",1),("hello",1)]
word_RDD=sc.parallelize(word_list,4)
word_RDD.reduceByKey(lambda a,b:a+b).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[191]: [(&#39;hello&#39;, 2), (&#39;world&#39;, 1)]</div>

# %%
input_str="I am new to Hadoop Hadoop is a Distributed Hadoop is a ecosystem"
input_list=input_str.split()
input_tu=[(i,1) for i in input_list]
print(input_tu)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;I&#39;, 1), (&#39;am&#39;, 1), (&#39;new&#39;, 1), (&#39;to&#39;, 1), (&#39;Hadoop&#39;, 1), (&#39;Hadoop&#39;, 1), (&#39;is&#39;, 1), (&#39;a&#39;, 1), (&#39;Distributed&#39;, 1), (&#39;Hadoop&#39;, 1), (&#39;is&#39;, 1), (&#39;a&#39;, 1), (&#39;ecosystem&#39;, 1)]
# </div>

# %%
word_RDD_1=sc.parallelize(input_tu,4)
word_RDD_1.reduceByKey(lambda a,b:a+b).takeOrdered(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[194]: [(&#39;Distributed&#39;, 1), (&#39;Hadoop&#39;, 3)]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
